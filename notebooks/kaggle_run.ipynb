# %%
# %%capture
# !add-apt-repository ppa:deadsnakes/ppa -y
# !apt-get update
# !apt-get install python3.8 python3.8-venv python3.8-dev -y
# !python3.8 -m venv /kaggle/working/py38_env

# %%
# %%capture

# !/kaggle/working/py38_env/bin/pip install --only-binary=:all: SimpleITK==2.2.1
# !/kaggle/working/py38_env/bin/pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113
# !/kaggle/working/py38_env/bin/pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu113/torch1.11.0/index.html

# %%
from kaggle_secrets import UserSecretsClient
import os
import sys

user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_TOKEN")

username = "Syfur007"
repo_name = "dissert"

print("Cloning private repository...")

if os.path.exists(repo_name):
    os.system(f"rm -rf {repo_name}")
    
# !git clone https://{token}@github.com/{username}/{repo_name}.git

os.chdir(f"/kaggle/working/{repo_name}")

# %%
# %%capture
# !/kaggle/working/py38_env/bin/pip install -r requirements.txt

# %%
experiments = [
    "configs/mkunet/mkunet_t_clinicdb_b8.yaml",
    "configs/mkunet/mkunet_t_clinicdb_b16.yaml",
]

# %%
for experiment in experiments:
    # !cat {experiment}
    # !/kaggle/working/py38_env/bin/python train.py --config {experiment} --dataset_dir /kaggle/input/datasets/syfur007/clinicdb-train-val-test-images-and-masks/ClinicDB
    # !/kaggle/working/py38_env/bin/python eval.py --config {experiment} --dataset_dir /kaggle/input/datasets/syfur007/clinicdb-train-val-test-images-and-masks/ClinicDB
    # !/kaggle/working/py38_env/bin/python eval.py --config {experiment} --dataset_dir /kaggle/input/datasets/syfur007/clinicdb-train-val-test-images-and-masks/ClinicDB --ensemble
